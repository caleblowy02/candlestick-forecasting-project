# %%
pip install yfinance ta-lib
# Out:
# Requirement already satisfied: yfinance in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (0.2.53)
# Requirement already satisfied: ta-lib in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (0.6.3)
# Requirement already satisfied: pandas>=1.3.0 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: requests>=2.31 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: setuptools in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from ta-lib) (75.8.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/jaehyeokchoi/candlesstick/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import talib

# Fetch AAPL stock data
df = yf.download("AAPL", start="2010-01-01", end="2024-01-01", interval="1d")
df.isna().sum()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df["Close"].shape
# Compute technical indicators
# Relative Strength Index (RSI)
df["RSI"] = talib.RSI(df["Close"].values.flatten(), timeperiod=3)
# Moving Average Convergence Divergence (MACD)
df["MACD"], df["MACD_signal"], df["MACD_hist"] = talib.MACD(df["Close"].values.flatten(), fastperiod=3, slowperiod=6, signalperiod=2)
# Average True Range (ATR)
df["ATR"] = talib.ATR(df["High"].values.flatten(), df["Low"].values.flatten(), df["Close"].values.flatten(), timeperiod=3)
# On-Balance Volume (OBV)
df["OBV"] = talib.OBV(df["Close"].values.flatten(), df["Volume"].astype(float).squeeze())

# Shift indicators for previous 3 days
df["RSI_1"] = df["RSI"].shift(1)
df["RSI_2"] = df["RSI"].shift(2)
df["RSI_3"] = df["RSI"].shift(3)

df["MACD_1"] = df["MACD"].shift(1)
df["MACD_2"] = df["MACD"].shift(2)
df["MACD_3"] = df["MACD"].shift(3)

df["MACD_signal_1"] = df["MACD_signal"].shift(1)
df["MACD_signal_2"] = df["MACD_signal"].shift(2)
df["MACD_signal_3"] = df["MACD_signal"].shift(3)

df["MACD_hist_1"] = df["MACD_hist"].shift(1)
df["MACD_hist_2"] = df["MACD_hist"].shift(2)
df["MACD_hist_3"] = df["MACD_hist"].shift(3)

df["ATR_1"] = df["ATR"].shift(1)
df["ATR_2"] = df["ATR"].shift(2)
df["ATR_3"] = df["ATR"].shift(3)

df["OBV_1"] = df["OBV"].shift(1)
df["OBV_2"] = df["OBV"].shift(2)
df["OBV_3"] = df["OBV"].shift(3)

df["Close_Change_Day1"] = round(((df["Close"].shift(-1) / df["Close"]) - 1) * 100,2)
df["Close_Change_Day2"] = round(((df["Close"].shift(-2) / df["Close"]) - 1) * 100,2)
df["Close_Change_Day3"] = round(((df["Close"].shift(-3) / df["Close"]) - 1) * 100,2)


# Update column selection
df = df[[
    # RSI
    "RSI", "RSI_1", "RSI_2", "RSI_3",
    # MACD
    "MACD", "MACD_1", "MACD_2", "MACD_3",
    "MACD_signal", "MACD_signal_1", "MACD_signal_2", "MACD_signal_3",
    "MACD_hist", "MACD_hist_1", "MACD_hist_2", "MACD_hist_3",
    # ATR
    "ATR", "ATR_1", "ATR_2", "ATR_3",
    # OBV
    "OBV", "OBV_1", "OBV_2", "OBV_3",
    # Close change
    "Close_Change_Day1", "Close_Change_Day2", "Close_Change_Day3"
]]

df.tail()
# Out:
# Price             RSI      RSI_1      RSI_2      RSI_3      MACD    MACD_1  \
# Ticker
# Date
# 2023-12-22  19.906676  29.814514  31.255289  57.146765 -0.595364 -0.343903
# 2023-12-26  15.876359  19.906676  29.814514  31.255289 -0.717272 -0.595364
# 2023-12-27  20.276799  15.876359  19.906676  29.814514 -0.637050 -0.717272
# 2023-12-28  40.395819  20.276799  15.876359  19.906676 -0.425794 -0.637050
# 2023-12-29  20.992465  40.395819  20.276799  15.876359 -0.513178 -0.425794
#
# Price         MACD_2    MACD_3 MACD_signal MACD_signal_1  ...     ATR_1  \
# Ticker                                                    ...
# Date                                                      ...
# 2023-12-22 -0.146358  0.375825   -0.466851     -0.209825  ...  2.808469
# 2023-12-26 -0.343903 -0.146358   -0.633798     -0.466851  ...  2.680793
# 2023-12-27 -0.595364 -0.343903   -0.635966     -0.633798  ...  2.138419
# 2023-12-28 -0.717272 -0.595364   -0.495851     -0.635966  ...  2.224153
# 2023-12-29 -0.637050 -0.717272   -0.507402     -0.495851  ...  1.983107
#
# Price          ATR_2     ATR_3           OBV         OBV_1         OBV_2  \
# Ticker
# Date
# 2023-12-22  2.433386  2.233588  1.821720e+10  1.825432e+10  1.830081e+10
# 2023-12-26  2.808469  2.433386  1.818828e+10  1.821720e+10  1.825432e+10
# 2023-12-27  2.680793  2.808469  1.823637e+10  1.818828e+10  1.821720e+10
# 2023-12-28  2.138419  2.680793  1.827042e+10  1.823637e+10  1.818828e+10
# 2023-12-29  2.224153  2.138419  1.822779e+10  1.827042e+10  1.823637e+10
#
# Price              OBV_3 Close_Change_Day1 Close_Change_Day2 Close_Change_Day3
# Ticker
# Date
# 2023-12-22  1.835305e+10             -0.28             -0.23             -0.01
# 2023-12-26  1.830081e+10              0.05              0.27             -0.27
# 2023-12-27  1.825432e+10              0.22             -0.32               NaN
# 2023-12-28  1.821720e+10             -0.54               NaN               NaN
# 2023-12-29  1.818828e+10               NaN               NaN               NaN
#
# [5 rows x 27 columns]

# %%
df.to_excel("tehcnical indicators.xlsx", engine="openpyxl")
